# %% [markdown]
# ## B- Handling Missing values by Dropping them

# %%
import pandas as pd

# %%
df=pd.read_csv('data.csv')
df.head()
# Out:
#    row_id     F_1_0     F_1_1     F_1_2     F_1_3     F_1_4     F_1_5  \
# 0       0 -0.354591 -0.464038  2.304115  0.734486  1.696395  0.136285
# 1       1  1.380940 -0.499626 -0.418548  1.911725 -0.826130 -1.715371
# 2       2  0.256023 -1.059874       NaN  0.345678  1.513814  1.243864
# 3       3 -0.728420 -2.432399 -2.453602 -0.020509  0.333397  0.086049
# 4       4  0.590212 -0.066127  0.468009 -1.096038  0.119399 -1.809710
#
#       F_1_6     F_1_7     F_1_8  ...     F_4_5     F_4_6     F_4_7     F_4_8  \
# 0 -0.518344  0.502640 -1.852504  ...  3.744152  0.794438  0.265185 -0.561809
# 1 -0.577091 -1.041486  0.596067  ... -2.895826 -0.738275  2.361818 -0.060753
# 2 -0.509648 -0.800481 -0.115945  ...  2.252834  0.472496  2.491386  0.353381
# 3 -1.787601  0.667011  0.761564  ...  2.004600 -4.664806 -0.847211 -0.264249
# 4  0.466358 -0.053196 -0.580320  ...  0.976937  2.558883  3.377724  0.846891
#
#       F_4_9    F_4_10    F_4_11    F_4_12    F_4_13    F_4_14
# 0  0.196480  0.373434  6.206995  3.809505  1.236486  1.182055
# 1  0.727249 -0.271882  5.232157 -4.218259 -2.724883 -0.063775
# 2 -0.260682 -0.000833 -0.116457 -2.131747  3.661499 -0.131576
# 3  0.664334 -0.557868  8.499483 -4.738799 -3.054611  0.494152
# 4  0.696032  0.554121 -5.979714 -2.869631  3.733057 -0.722943
#
# [5 rows x 81 columns]

# %%
df.shape
# Out:
# (1000000, 81)

# %%
df.isnull()
# Out:
#         row_id  F_1_0  F_1_1  F_1_2  F_1_3  F_1_4  F_1_5  F_1_6  F_1_7  F_1_8  \
# 0        False  False  False  False  False  False  False  False  False  False
# 1        False  False  False  False  False  False  False  False  False  False
# 2        False  False  False   True  False  False  False  False  False  False
# 3        False  False  False  False  False  False  False  False  False  False
# 4        False  False  False  False  False  False  False  False  False  False
# ...        ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 999995   False  False  False  False  False  False  False  False  False  False
# 999996   False  False  False  False  False  False  False  False  False  False
# 999997   False  False  False  False  False  False  False  False  False  False
# 999998   False  False  False  False  False  False  False  False  False  False
# 999999   False  False  False  False  False  False  False  False  False  False
#
#         ...  F_4_5  F_4_6  F_4_7  F_4_8  F_4_9  F_4_10  F_4_11  F_4_12  \
# 0       ...  False  False  False  False  False   False   False   False
# 1       ...  False  False  False  False  False   False   False   False
# 2       ...  False  False  False  False  False   False   False   False
# 3       ...  False  False  False  False  False   False   False   False
# 4       ...  False  False  False  False  False   False   False   False
# ...     ...    ...    ...    ...    ...    ...     ...     ...     ...
# 999995  ...  False  False  False  False  False   False   False   False
# 999996  ...  False  False  False  False  False   False   False   False
# 999997  ...  False  False  False   True  False   False   False   False
# 999998  ...  False  False  False  False  False   False   False   False
# 999999  ...  False  False  False  False  False   False   False   False
#
#         F_4_13  F_4_14
# 0        False   False
# 1        False   False
# 2        False   False
# 3        False   False
# 4        False   False
# ...        ...     ...
# 999995   False   False
# 999996   False   False
# 999997   False   False
# 999998   False   False
# 999999   False   False
#
# [1000000 rows x 81 columns]

# %%
df.isnull().sum()
# Out:
# row_id        0
# F_1_0     18397
# F_1_1     18216
# F_1_2     18008
# F_1_3     18250
#           ...
# F_4_10    18225
# F_4_11    18119
# F_4_12    18306
# F_4_13    17995
# F_4_14    18267
# Length: 81, dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 1000000

# %%
df1 = df.sample(frac =.05)
df1.shape
# Out:
# (50000, 81)

# %%
import datasist as ds #import datasist library
ds.structdata.describe(df1)
# Out:
# First five data points
#         row_id     F_1_0     F_1_1     F_1_2     F_1_3     F_1_4     F_1_5  \
# 66440    66440  0.576888 -0.929215 -0.453247  0.534329  2.444957 -0.201280
# 865729  865729 -1.491360 -0.907823 -1.407433 -0.055422  0.701777 -2.426083
# 621768  621768 -1.418235  0.725810 -0.902319 -1.912227  0.120245 -0.120803
# 536878  536878  0.205750  0.097932  0.329225 -0.883767 -0.869681 -0.050834
# 873723  873723  0.662098  0.187522 -1.202724  1.015504 -0.883985  0.878627
#
#            F_1_6     F_1_7     F_1_8  ...     F_4_5     F_4_6     F_4_7  \
# 66440   0.355676  0.479045  1.878210  ...  3.373339  2.441506  1.695217
# 865729  1.124349  0.432763 -1.888765  ...  0.592536  1.959306 -3.969096
# 621768 -0.875826  0.541284 -0.580062  ... -0.207465 -1.561835  0.142012
# 536878 -1.982123 -0.287001 -0.206611  ... -2.287999  0.324857  5.880693
# 873723 -0.202328  0.485628  2.218673  ... -4.360134  2.577577  0.608408
#
#            F_4_8     F_4_9    F_4_10    F_4_11    F_4_12    F_4_13    F_4_14
# 66440  -0.230183  0.241400 -1.264886  2.049006  0.269202 -3.241235  0.191713
# 865729  0.090823  0.292639 -0.200105  0.434302 -1.429682 -1.071155 -1.141711
# 621768 -0.499447  0.776761  0.354353       NaN  2.365741  0.341855  0.831607
# 536878  0.781921 -0.609023 -1.125385  3.528888  2.806618 -0.720875  0.998018
# 873723  0.213126  0.369706 -0.046786  1.423094 -0.247971 -1.238734  0.860772
#
# [5 rows x 81 columns]
# Random five data points
#         row_id     F_1_0     F_1_1     F_1_2     F_1_3     F_1_4     F_1_5  \
# 563640  563640 -0.510557 -0.079561  0.618138 -0.308619 -0.086152  0.286273
# 848203  848203  0.486248 -0.066412  0.167905  0.417930  1.599368       NaN
# 348341  348341  1.096948  1.061603 -1.394869 -0.648727  0.956090 -1.273951
# 521185  521185  0.434327 -1.503117 -1.141488  0.852515 -0.321773 -1.246964
# 455587  455587 -0.742840  0.611994  0.250987  1.021903 -1.359428  1.011396
#
#            F_1_6     F_1_7     F_1_8  ...     F_4_5     F_4_6     F_4_7  \
# 563640  0.626217  0.614853  1.274931  ... -0.788151 -3.494228  3.055058
# 848203 -0.954324  0.287097  1.213341  ...  3.151896 -0.450997  1.626966
# 348341 -0.503370 -0.448995 -0.682028  ... -1.157571 -1.030292  4.529117
# 521185  1.075209  0.619265  1.164722  ...  3.087149  3.324238 -0.796161
# 455587  0.535935       NaN -0.362656  ...  1.210808 -0.948924  0.706165
#
#            F_4_8     F_4_9    F_4_10    F_4_11    F_4_12    F_4_13    F_4_14
# 563640 -0.677941  0.981497  1.062454 -2.048092  6.988401 -1.655919  0.472870
# 848203 -0.494477  0.605860 -0.586446  6.809077 -1.752694  2.633558  0.403937
# 348341 -0.449095 -1.037090 -0.141040  0.458017  2.387885  0.979652  0.232134
# 521185  0.968018 -0.272601  0.429499 -9.360765 -3.158313  5.985510 -1.549041
# 455587 -0.686694 -0.647764 -1.038799  8.396080 -2.040680 -1.272023  1.149174
#
# [5 rows x 81 columns]
# Last five data points
#         row_id     F_1_0     F_1_1     F_1_2     F_1_3     F_1_4     F_1_5  \
# 565721  565721  0.804161 -0.636021 -0.131435 -0.580734 -0.281547  0.163935
# 970619  970619       NaN  0.403960  0.163688  0.624360  0.825742  1.322610
# 87773    87773 -1.007155  1.561189 -1.946487 -0.536680  0.787145  1.100409
# 872781  872781  0.096781 -1.548178 -0.127306  0.236410 -0.091184 -0.406763
# 286828  286828 -0.724918 -1.398970 -0.251790  0.784980 -0.201155 -1.224644
#
#            F_1_6     F_1_7     F_1_8  ...     F_4_5     F_4_6     F_4_7  \
# 565721  1.255470 -0.756116  0.188076  ... -0.899816  4.084710 -2.582655
# 970619 -0.121175 -0.747462  0.456690  ... -0.922007 -0.127178  1.312174
# 87773  -0.678230 -0.186549 -1.241323  ...  0.952575  1.276865  2.308709
# 872781 -1.008168 -0.313749 -1.270149  ... -0.961127 -0.127401  1.811017
# 286828 -0.647519  0.177683 -2.306162  ...  0.149235 -1.709157  0.351232
#
#            F_4_8     F_4_9    F_4_10    F_4_11    F_4_12    F_4_13    F_4_14
# 565721  0.236718  0.114963  0.150978 -2.046430  0.711388 -0.412130 -0.716923
# 970619  0.064063 -0.063305 -1.018712  0.762567  2.079191  0.167190  0.257625
# 87773  -1.068384  1.439041 -0.292872  9.809533 -2.176006 -1.475583  0.802903
# 872781  0.622682 -0.006826  0.259577       NaN  5.807918  2.038191  0.516495
# 286828 -1.483953 -0.433358 -0.837679  9.855815 -1.669820 -2.241545  0.478325
#
# [5 rows x 81 columns]
# Shape of  data set: (50000, 81)
#
#
# Size of  data set: 4050000
#
#
# Data Types
# Note: All Non-numerical features are identified as objects in pandas
#        Data Type
# row_id     int64
# F_1_0    float64
# F_1_1    float64
# F_1_2    float64
# F_1_3    float64
# ...          ...
# F_4_10   float64
# F_4_11   float64
# F_4_12   float64
# F_4_13   float64
# F_4_14   float64
#
# [81 rows x 1 columns]
# Numerical Features in Data set
# ['row_id', 'F_1_0', 'F_1_1', 'F_1_2', 'F_1_3', 'F_1_4', 'F_1_5', 'F_1_6', 'F_1_7', 'F_1_8', 'F_1_9', 'F_1_10', 'F_1_11', 'F_1_12', 'F_1_13', 'F_1_14', 'F_2_0', 'F_2_1', 'F_2_2', 'F_2_3', 'F_2_4', 'F_2_5', 'F_2_6', 'F_2_7', 'F_2_8', 'F_2_9', 'F_2_10', 'F_2_11', 'F_2_12', 'F_2_13', 'F_2_14', 'F_2_15', 'F_2_16', 'F_2_17', 'F_2_18', 'F_2_19', 'F_2_20', 'F_2_21', 'F_2_22', 'F_2_23', 'F_2_24', 'F_3_0', 'F_3_1', 'F_3_2', 'F_3_3', 'F_3_4', 'F_3_5', 'F_3_6', 'F_3_7', 'F_3_8', 'F_3_9', 'F_3_10', 'F_3_11', 'F_3_12', 'F_3_13', 'F_3_14', 'F_3_15', 'F_3_16', 'F_3_17', 'F_3_18', 'F_3_19', 'F_3_20', 'F_3_21', 'F_3_22', 'F_3_23', 'F_3_24', 'F_4_0', 'F_4_1', 'F_4_2', 'F_4_3', 'F_4_4', 'F_4_5', 'F_4_6', 'F_4_7', 'F_4_8', 'F_4_9', 'F_4_10', 'F_4_11', 'F_4_12', 'F_4_13', 'F_4_14']
#
#
# Categorical Features in Data set
# []
# Statistical Description of Columns
#               row_id         F_1_0         F_1_1         F_1_2         F_1_3  \
# count   50000.000000  49070.000000  49085.000000  49089.000000  49112.000000
# mean   502049.084980     -0.001653     -0.004670     -0.004722     -0.001604
# std    288297.786043      1.004455      0.999832      1.002075      1.001125
# min        47.000000     -4.180855     -4.465650     -4.277920     -4.250527
# 25%    255132.000000     -0.680348     -0.685188     -0.681504     -0.682810
# 50%    502393.000000      0.002521     -0.004985     -0.002175     -0.002086
# 75%    753112.750000      0.674231      0.672216      0.678556      0.675751
# max    999996.000000      4.119357      4.286882      3.808045      4.002225
#
#               F_1_4         F_1_5         F_1_6         F_1_7         F_1_8  \
# count  49075.000000  49114.000000  49114.000000  49070.000000  49048.000000
# mean       0.004027      0.001574      0.004110     -0.056671     -0.001158
# std        1.001864      1.001216      0.996536      0.723770      1.005483
# min       -3.890909     -4.231703     -4.294184     -5.494300     -3.975812
# 25%       -0.663173     -0.675295     -0.670162     -0.494008     -0.677702
# 50%        0.001999      0.000744      0.002064      0.008085     -0.000211
# 75%        0.675524      0.682451      0.674198      0.452049      0.676685
# max        4.819838      4.036326      4.119271      2.285879      4.033393
#
#        ...         F_4_5         F_4_6         F_4_7         F_4_8  \
# count  ...  49123.000000  49094.000000  49060.000000  49079.000000
# mean   ...      0.332278     -0.003575      0.343589     -0.074566
# std    ...      2.343643      2.301302      2.350015      0.777086
# min    ...     -9.804510     -9.437229     -8.890329     -7.102537
# 25%    ...     -1.263650     -1.585892     -1.223747     -0.520640
# 50%    ...      0.292135     -0.077951      0.385629      0.013691
# 75%    ...      1.907496      1.511341      1.926252      0.474421
# max    ...     10.309558      9.966478     10.281500      2.077872
#
#               F_4_9        F_4_10        F_4_11        F_4_12        F_4_13  \
# count  49094.000000  49109.000000  49090.000000  49096.000000  49053.000000
# mean      -0.081230      0.038307      0.600961      0.310166      0.312354
# std        0.806298      0.708280      4.981120      2.378500      2.353699
# min       -5.517574     -4.365112    -20.420330     -9.896390     -9.117296
# 25%       -0.575451     -0.384295     -2.729151     -1.280167     -1.308428
# 50%       -0.030820      0.102895      0.279068      0.309883      0.282120
# 75%        0.480378      0.527534      3.691832      1.916695      1.885804
# max        2.508056      2.327079     24.371945     11.235084     11.901409
#
#              F_4_14
# count  49081.000000
# mean       0.037795
# std        0.781474
# min       -5.488591
# 25%       -0.398292
# 50%        0.133448
# 75%        0.579214
# max        2.521663
#
# [8 rows x 81 columns]
# Description of Categorical Features
# C:\Users\PC\anaconda3\lib\site-packages\datasist\structdata.py:81: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if len(date_cols) is not 0:
# C:\Users\PC\anaconda3\lib\site-packages\datasist\structdata.py:81: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if len(date_cols) is not 0:
# C:\Users\PC\anaconda3\lib\site-packages\datasist\structdata.py:81: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if len(date_cols) is not 0:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [8], in <cell line: 2>()
#       1 import datasist as ds #import datasist library
# ----> 2 ds.structdata.describe(df1)
#
# File ~\anaconda3\lib\site-packages\datasist\structdata.py:99, in describe(data, name, date_cols, show_categories, plot_missing)
#      97 print('Description of Categorical Features')
#      98 if cat_features != None:
# ---> 99     display(data.describe(include=[np.object, pd.Categorical]).T)
#     100     _space()
#     102 print('Unique class Count of Categorical features')
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:10225, in NDFrame.describe(self, percentiles, include, exclude, datetime_is_numeric)
#    9976 @final
#    9977 def describe(
#    9978     self: NDFrameT,
#    (...)
#    9982     datetime_is_numeric=False,
#    9983 ) -> NDFrameT:
#    9984     """
#    9985     Generate descriptive statistics.
#    9986
#    (...)
#   10223     max            NaN      3.0
#   10224     """
# > 10225     return describe_ndframe(
#   10226         obj=self,
#   10227         include=include,
#   10228         exclude=exclude,
#   10229         datetime_is_numeric=datetime_is_numeric,
#   10230         percentiles=percentiles,
#   10231     )
#
# File ~\anaconda3\lib\site-packages\pandas\core\describe.py:94, in describe_ndframe(obj, include, exclude, datetime_is_numeric, percentiles)
#      86 else:
#      87     describer = DataFrameDescriber(
#      88         obj=cast("DataFrame", obj),
#      89         include=include,
#      90         exclude=exclude,
#      91         datetime_is_numeric=datetime_is_numeric,
#      92     )
# ---> 94 result = describer.describe(percentiles=percentiles)
#      95 return cast(NDFrameT, result)
#
# File ~\anaconda3\lib\site-packages\pandas\core\describe.py:177, in DataFrameDescriber.describe(self, percentiles)
#     174     ldesc.append(describe_func(series, percentiles))
#     176 col_names = reorder_columns(ldesc)
# --> 177 d = concat(
#     178     [x.reindex(col_names, copy=False) for x in ldesc],
#     179     axis=1,
#     180     sort=False,
#     181 )
#     182 d.columns = data.columns.copy()
#     183 return d
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\reshape\concat.py:347, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     143 @deprecate_nonkeyword_arguments(version=None, allowed_args=["objs"])
#     144 def concat(
#     145     objs: Iterable[NDFrame] | Mapping[Hashable, NDFrame],
#    (...)
#     154     copy: bool = True,
#     155 ) -> DataFrame | Series:
#     156     """
#     157     Concatenate pandas objects along a particular axis with optional set logic
#     158     along the other axes.
#    (...)
#     345     ValueError: Indexes have overlapping values: ['a']
#     346     """
# --> 347     op = _Concatenator(
#     348         objs,
#     349         axis=axis,
#     350         ignore_index=ignore_index,
#     351         join=join,
#     352         keys=keys,
#     353         levels=levels,
#     354         names=names,
#     355         verify_integrity=verify_integrity,
#     356         copy=copy,
#     357         sort=sort,
#     358     )
#     360     return op.get_result()
#
# File ~\anaconda3\lib\site-packages\pandas\core\reshape\concat.py:404, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     401     objs = list(objs)
#     403 if len(objs) == 0:
# --> 404     raise ValueError("No objects to concatenate")
#     406 if keys is None:
#     407     objs = list(com.not_none(*objs))
#
# ValueError: No objects to concatenate

# %%
ds.structdata.display_missing(df1)
# Out:
#    features  missing_counts  missing_percent
# 0    row_id               0              0.0
# 1     F_1_0             930              1.9
# 2     F_1_1             915              1.8
# 3     F_1_2             911              1.8
# 4     F_1_3             888              1.8
# ..      ...             ...              ...
# 76   F_4_10             891              1.8
# 77   F_4_11             910              1.8
# 78   F_4_12             904              1.8
# 79   F_4_13             947              1.9
# 80   F_4_14             919              1.8
#
# [81 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
ds.visualizations.countplot(df1)

# %%
ds.visualizations.histogram(df1)
# Out:
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df1.isnull().sum()
# Out:
# row_id      0
# F_1_0     866
# F_1_1     912
# F_1_2     896
# F_1_3     984
#          ...
# F_4_10    919
# F_4_11    940
# F_4_12    902
# F_4_13    870
# F_4_14    854
# Length: 81, dtype: int64

# %%
df1.isnull().sum().sum()
# Out:
# 50332

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50000 entries, 66440 to 286828
# Data columns (total 81 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   row_id  50000 non-null  int64
#  1   F_1_0   49070 non-null  float64
#  2   F_1_1   49085 non-null  float64
#  3   F_1_2   49089 non-null  float64
#  4   F_1_3   49112 non-null  float64
#  5   F_1_4   49075 non-null  float64
#  6   F_1_5   49114 non-null  float64
#  7   F_1_6   49114 non-null  float64
#  8   F_1_7   49070 non-null  float64
#  9   F_1_8   49048 non-null  float64
#  10  F_1_9   49048 non-null  float64
#  11  F_1_10  49078 non-null  float64
#  12  F_1_11  49081 non-null  float64
#  13  F_1_12  49152 non-null  float64
#  14  F_1_13  49085 non-null  float64
#  15  F_1_14  49061 non-null  float64
#  16  F_2_0   50000 non-null  int64
#  17  F_2_1   50000 non-null  int64
#  18  F_2_2   50000 non-null  int64
#  19  F_2_3   50000 non-null  int64
#  20  F_2_4   50000 non-null  int64
#  21  F_2_5   50000 non-null  int64
#  22  F_2_6   50000 non-null  int64
#  23  F_2_7   50000 non-null  int64
#  24  F_2_8   50000 non-null  int64
#  25  F_2_9   50000 non-null  int64
#  26  F_2_10  50000 non-null  int64
#  27  F_2_11  50000 non-null  int64
#  28  F_2_12  50000 non-null  int64
#  29  F_2_13  50000 non-null  int64
#  30  F_2_14  50000 non-null  int64
#  31  F_2_15  50000 non-null  int64
#  32  F_2_16  50000 non-null  int64
#  33  F_2_17  50000 non-null  int64
#  34  F_2_18  50000 non-null  int64
#  35  F_2_19  50000 non-null  int64
#  36  F_2_20  50000 non-null  int64
#  37  F_2_21  50000 non-null  int64
#  38  F_2_22  50000 non-null  int64
#  39  F_2_23  50000 non-null  int64
#  40  F_2_24  50000 non-null  int64
#  41  F_3_0   49115 non-null  float64
#  42  F_3_1   49071 non-null  float64
#  43  F_3_2   49064 non-null  float64
#  44  F_3_3   49136 non-null  float64
#  45  F_3_4   49073 non-null  float64
#  46  F_3_5   49079 non-null  float64
#  47  F_3_6   49089 non-null  float64
#  48  F_3_7   49121 non-null  float64
#  49  F_3_8   49065 non-null  float64
#  50  F_3_9   49100 non-null  float64
#  51  F_3_10  49052 non-null  float64
#  52  F_3_11  49086 non-null  float64
#  53  F_3_12  49080 non-null  float64
#  54  F_3_13  49095 non-null  float64
#  55  F_3_14  49024 non-null  float64
#  56  F_3_15  49070 non-null  float64
#  57  F_3_16  49109 non-null  float64
#  58  F_3_17  49025 non-null  float64
#  59  F_3_18  49042 non-null  float64
#  60  F_3_19  49090 non-null  float64
#  61  F_3_20  49016 non-null  float64
#  62  F_3_21  49074 non-null  float64
#  63  F_3_22  49059 non-null  float64
#  64  F_3_23  49098 non-null  float64
#  65  F_3_24  49076 non-null  float64
#  66  F_4_0   49126 non-null  float64
#  67  F_4_1   49110 non-null  float64
#  68  F_4_2   49090 non-null  float64
#  69  F_4_3   49137 non-null  float64
#  70  F_4_4   49135 non-null  float64
#  71  F_4_5   49123 non-null  float64
#  72  F_4_6   49094 non-null  float64
#  73  F_4_7   49060 non-null  float64
#  74  F_4_8   49079 non-null  float64
#  75  F_4_9   49094 non-null  float64
#  76  F_4_10  49109 non-null  float64
#  77  F_4_11  49090 non-null  float64
#  78  F_4_12  49096 non-null  float64
#  79  F_4_13  49053 non-null  float64
#  80  F_4_14  49081 non-null  float64
# dtypes: float64(55), int64(26)
# memory usage: 31.3 MB

# %%
df1.describe()
# Out:
#               row_id         F_1_0         F_1_1         F_1_2         F_1_3  \
# count   50000.000000  49070.000000  49085.000000  49089.000000  49112.000000
# mean   502049.084980     -0.001653     -0.004670     -0.004722     -0.001604
# std    288297.786043      1.004455      0.999832      1.002075      1.001125
# min        47.000000     -4.180855     -4.465650     -4.277920     -4.250527
# 25%    255132.000000     -0.680348     -0.685188     -0.681504     -0.682810
# 50%    502393.000000      0.002521     -0.004985     -0.002175     -0.002086
# 75%    753112.750000      0.674231      0.672216      0.678556      0.675751
# max    999996.000000      4.119357      4.286882      3.808045      4.002225
#
#               F_1_4         F_1_5         F_1_6         F_1_7         F_1_8  \
# count  49075.000000  49114.000000  49114.000000  49070.000000  49048.000000
# mean       0.004027      0.001574      0.004110     -0.056671     -0.001158
# std        1.001864      1.001216      0.996536      0.723770      1.005483
# min       -3.890909     -4.231703     -4.294184     -5.494300     -3.975812
# 25%       -0.663173     -0.675295     -0.670162     -0.494008     -0.677702
# 50%        0.001999      0.000744      0.002064      0.008085     -0.000211
# 75%        0.675524      0.682451      0.674198      0.452049      0.676685
# max        4.819838      4.036326      4.119271      2.285879      4.033393
#
#        ...         F_4_5         F_4_6         F_4_7         F_4_8  \
# count  ...  49123.000000  49094.000000  49060.000000  49079.000000
# mean   ...      0.332278     -0.003575      0.343589     -0.074566
# std    ...      2.343643      2.301302      2.350015      0.777086
# min    ...     -9.804510     -9.437229     -8.890329     -7.102537
# 25%    ...     -1.263650     -1.585892     -1.223747     -0.520640
# 50%    ...      0.292135     -0.077951      0.385629      0.013691
# 75%    ...      1.907496      1.511341      1.926252      0.474421
# max    ...     10.309558      9.966478     10.281500      2.077872
#
#               F_4_9        F_4_10        F_4_11        F_4_12        F_4_13  \
# count  49094.000000  49109.000000  49090.000000  49096.000000  49053.000000
# mean      -0.081230      0.038307      0.600961      0.310166      0.312354
# std        0.806298      0.708280      4.981120      2.378500      2.353699
# min       -5.517574     -4.365112    -20.420330     -9.896390     -9.117296
# 25%       -0.575451     -0.384295     -2.729151     -1.280167     -1.308428
# 50%       -0.030820      0.102895      0.279068      0.309883      0.282120
# 75%        0.480378      0.527534      3.691832      1.916695      1.885804
# max        2.508056      2.327079     24.371945     11.235084     11.901409
#
#              F_4_14
# count  49081.000000
# mean       0.037795
# std        0.781474
# min       -5.488591
# 25%       -0.398292
# 50%        0.133448
# 75%        0.579214
# max        2.521663
#
# [8 rows x 81 columns]

# %%
import missingno as msno
# %matplotlib inline
msno.matrix(df1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## B- Handling Missing values by Drop Missing Values

# %%
df2=df1.dropna()

# %%
df2.isnull().sum()
# Out:
# row_id    0
# F_1_0     0
# F_1_1     0
# F_1_2     0
# F_1_3     0
#          ..
# F_4_10    0
# F_4_11    0
# F_4_12    0
# F_4_13    0
# F_4_14    0
# Length: 81, dtype: int64

# %%
df2.isnull().sum().sum()
# Out:
# 0

# %%
X=df2.iloc[:,1:-1].values
y=df2.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
print(X.shape)
# Out:
# (17971, 79)

# %%
from sklearn import utils
print(utils.multiclass.type_of_target(y_train))
# Out:
# continuous

# %%
from sklearn import utils
print(utils.multiclass.type_of_target(y_train))

from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
y_train= label_encoder.fit_transform(y_train)
print(utils.multiclass.type_of_target(y_train))
# Out:
# continuous
# multiclass

# %% [markdown]
# ## 1- Decision Tree for Drop Missing Values

# %%
from sklearn.tree import DecisionTreeClassifier
tree=DecisionTreeClassifier(criterion='entropy',random_state=0)
tree.fit(X_train,y_train)
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
tree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
print('The accuracy of Decision Tree : ',tree.score(X_train,y_train))
# Out:
# The accuracy of Decision Tree :  1.0

# %%
prediction=tree.predict(X_test)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
prediction=tree.predict(X_test)

# %%
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title("Decision Tree")
plt.scatter(y_test,prediction)
plt.plot([-4,2],[0,15000],color='red')
plt.show()

# %% [markdown]
# ## 2- Random Forest for Drop Missing Values

# %%
from sklearn.ensemble import RandomForestClassifier
forst=RandomForestClassifier(n_estimators=10,criterion='entropy',random_state=0)
forst.fit(X_train,y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10, random_state=0)

# %%
print('The accuracy of Random Forest : ',forst.score(X_train,y_train))
# Out:
# The accuracy of Random Forest :  0.9993739565943238

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
forst.fit(X_train,y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10, random_state=0)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
prediction=forst.predict(X_test)

# %%
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title("Random Forest")
plt.scatter(y_test,prediction)
plt.plot([-4,2],[0,14000],color='red')
plt.show()

# %% [markdown]
# # 3- Linear Regression for Drop Missing Values

# %%
from sklearn.linear_model import LinearRegression
Lin=LinearRegression()
Lin.fit(X_train,y_train)

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
Lin.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print('The accuracy of LinearRegression: ',Lin.score(X_train,y_train))
# Out:
# The accuracy of LinearRegression:  0.9027374749397603

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
Lin.intercept_
# Out:
# 7171.521076794657

# %%
prediction=Lin.predict(X_test)

# %%
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title("Linear Regression")
plt.scatter(y_test,prediction)
plt.plot([-4,2],[-10000,20000],color='red')
plt.show()
